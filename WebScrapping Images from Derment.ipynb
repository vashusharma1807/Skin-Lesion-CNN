# %% [markdown]
# # This Notebook Extracts Images from Derment Website for all catogeries from the 1st table

# %% [markdown]
# Imports

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
from urllib.parse import urljoin 
import re
import os.path
import pickle
import urllib.request

# %%
#Constants - path definitions
HOME_PAGE = "http://www.dermnet.com/dermatology-pictures-skin-disease-pictures/"
DOMAIN_PAGE = "http://www.dermnet.com/"
IMAGE_DIR = "E:/Major Project 2022/downloaded_dataset"

# %% [markdown]
# Getting Images from Derment Webpage

# %%
def openPg(url):
    """Opens a web page for parsing.
    
    Args:
        url: a web address.
    
    Returns:
        BeautifulSoup object to parse.
    """
    print("Url open")
    url = url.replace(" ","%20")
    html = urlopen(url)
    soup = BeautifulSoup(html, "lxml")
    return soup

# %% [markdown]
# fun getClassImages - A function that returns a list of all images for a given skin disease class.
# fun getClassCategories - A function that returns a list of all subcategories for a given skin disease.

# %%
def getClassImages(class_url):
    """Returns all images for a class label, including all child (webpage) categories.
    
    Args:
        class_url: a web address for a skin disease class.
    
    Returns:
        class_images: A list containing all image links for a class label.
    """
    print(class_url)
    class_images = []
    cat_urls = getClassCategories(class_url)
    for url in cat_urls:
        class_images.extend(getCategoryImages(url))
    return class_images

def getClassCategories(class_url):
    """Returns all category urls for a skin disease class.
    
    Args:
        class_url: a web address for a skin disease class.
    
    Returns:
        categories: A list containing category urls.
    """
    soup = openPg(class_url)
    cat_links = soup.find("table").find_all("a")
    categories = []
    for link in cat_links:
        abs_link = urljoin(DOMAIN_PAGE, link.get('href'))
        categories.append(abs_link)
    return categories

# %% [markdown]
# getCategoryImages - Helper functions to get all images within a category.
#
# For a given category, we parse through paginated pages of thumbnail images and add the full image path to a list.

# %%
def getCategoryImages(cat_url):
    """Captures all category image urls within a series of paginated links.
    
    Args:
        cat_url: a category web address.
    
    Returns:
        cat_images: A list containing image urls.
    """
    cat_images = []
    cat_thumbpgs = []
    #add to category image list
    addPgImages(cat_url, cat_images)
    cat_thumbpgs = getAllThumbPgs(cat_url)    
    # more pages in category, add images from those thumbnail pages
    if cat_thumbpgs: 
        for page in cat_thumbpgs:
            addPgImages(page, cat_images)
    return cat_images

def getAllThumbPgs(cat_url):
    """Returns pagnated links associated to a category, if any.
    
    Args:
        cat_url: a category web address.
    
    Returns:
        thumb_pgs: A list of pagnated link addresses.
    """
    soup = openPg(cat_url)
    pages = soup.find("div","pagination")
    thumb_pgs = []
    if pages:  #there are multiple pages for this category
        for page in pages:
            if page.name == 'a' and page.string != 'Next':
                thumb_pgs.append(urljoin(DOMAIN_PAGE, page['href']))
    return thumb_pgs

def addPgImages(url,image_list):
    """Finds all image links in a webpage and adds them to the image list.
    
    Args:
        url: a web address for a pagnated category page.
        image_list: a list of image urls
    
    Returns:
        Nothing.
    """
    soup = openPg(url)
    thumbnails = soup.find_all("div","thumbnails")
    if thumbnails: ## there are thumbnails actually on the page
        for thumb in thumbnails:
            thumb_link = thumb.img['src']
            #use full image link instead of thumbnail link
            image_link = re.sub(r'Thumb',"",thumb_link)
            image_list.append(image_link)

# %% [markdown]
# The Dermnet webpage is structured as follows:
#
#     Home Page (Root)
#         Class Label Links
#             Class Categories Links
#                 Paginated pages of images
#
# We traverse through the webpage hierarchy and build a flattened dictionary of (class: list of image links)

# %%
#createImageDict - Function to load or create a dictionary of classes and their associated image links.

# %%
def createImageDict(dict_file):
    """Create image dictionary and serialize to disk (pickle). Unpickle to dictionary object if already exists.
    
    Args:
        dict_file: Absolute path + filename of pickle file object.
    
    Returns:
        image_dict: dictionary containing image urls for 23 skin disease classes.
    """
    # load dictionary object hierarchy if pickled file exists
    if os.path.exists(dict_file):
        print("Loading image dictionary %s" % dict_file)
        with open(dict_file, 'rb') as f:
            try:
                img_dict = pickle.load(f)
                print("Loaded image dictionary.")
                return img_dict
            except:
                print("Failure to load: %s. Creating dictionary. " % dict_file)
    
    #create dictionary by parsing Dermnet
    #open website root directory and get class links
    soup = openPg(HOME_PAGE)
    class_links = soup.find("table").find_all("a")

    print("Populating image dictionary...")
    img_dict = {}
    for link in class_links:
        print("class links")
        abs_link = urljoin(DOMAIN_PAGE, link.get('href'))
        print("class links1")
        class_name = re.sub(r'[^a-z0-9A-Z\s]+', '', link.string)
        #add to final dictionary {class_name: list of image links}
        print("class links 2")
        img_dict[class_name] = getClassImages(abs_link)
        print("class links 3")

    print("Image dictionary populated. Total classes: %s" % len(img_dict))

    #save dictionary to pickle file
    with open(dict_file, 'wb') as f:
        try:
            pickle.dump(img_dict, f)
            print("Saved image dictionary to %s" % dict_file)
        except:
            print("Failure to save dictionary %s. \nPlease investigate. " % dict_file)

    return img_dict

# %% [markdown]
# ##Main Function

# %%
## load existing class-to-image url dictionary, or scrape website.
img_dictionary = createImageDict(os.path.join(IMAGE_DIR,'imageUrls.p'))

## Downloading pictures from dictionary
for key, class_imgs in img_dictionary.items():

    print("Processing class: %s" %key)

    #create class folders, if it doesn't exist
    class_path = os.path.join(IMAGE_DIR,key)
    if not os.path.exists(class_path):
        print("Creating dir in: %s" %class_path)
        os.mkdir(class_path)
    else:
        print("Found Dir")

    #check if more images to be added to class dir
    num_dirImgs = len([name for name in os.listdir(class_path) if os.path.isfile(os.path.join(class_path, name))])
    count = 0
    if not num_dirImgs == len(class_imgs):
        for img in class_imgs:

            img_name = os.path.basename(img)
            file_name = os.path.join(class_path,img_name)

            if os.path.isfile(file_name):
                print("Skipping: " + img_name + " has already downloaded.")
            else:
                #download image
                if class_imgs.index(img) % 10 == 0:
                    print("Downloading image #%s: %s" %(class_imgs.index(img),img_name))
                
                try:
                    img=img.replace(" ","%20")
                    #img = urllib.parse.quote(img)
                    print(img)
                    f = urlopen(img).read()
                    open(file_name, 'wb').write(f)
                except:
                    print("Error in Parsing this image, due to url issue")

    print("Download complete for: %s" %key)

print("Scraping Complete.")
# Out:
# Loading image dictionary E:/Major Project 2022/downloaded_dataset\imageUrls.p
# Loaded image dictionary.
# Processing class: Acne and Rosacea Photos
# Found Dir
# Skipping: acne-closed-comedo-002.jpg has already downloaded.
# Skipping: acne-closed-comedo-003.jpg has already downloaded.
# Skipping: acne-closed-comedo-1.jpg has already downloaded.
# Skipping: acne-closed-comedo-1.jpg has already downloaded.
# Skipping: acne-closed-comedo-10.jpg has already downloaded.
# Skipping: acne-closed-comedo-11.jpg has already downloaded.
# Skipping: acne-closed-comedo-12.jpg has already downloaded.
# Skipping: acne-closed-comedo-13.jpg has already downloaded.
# Skipping: acne-closed-comedo-14.jpg has already downloaded.
# Skipping: acne-closed-comedo-15.jpg has already downloaded.
# Skipping: acne-closed-comedo-16.jpg has already downloaded.
# Skipping: acne-closed-comedo-17.jpg has already downloaded.
# Skipping: acne-closed-comedo-18.jpg has already downloaded.
# Skipping: acne-closed-comedo-19.jpg has already downloaded.
# Skipping: acne-closed-comedo-2.jpg has already downloaded.
# Skipping: acne-closed-comedo-20.jpg has already downloaded.
# Skipping: acne-closed-comedo-21.jpg has already downloaded.
# Skipping: acne-closed-comedo-22.jpg has already downloaded.
# Skipping: acne-closed-comedo-23.jpg has already downloaded.
# Skipping: acne-closed-comedo-24.jpg has already downloaded.
# Skipping: acne-closed-comedo-25.jpg has already downloaded.
# Skipping: acne-closed-comedo-26.jpg has already downloaded.
# Skipping: acne-closed-comedo-27.jpg has already downloaded.
# Skipping: acne-closed-comedo-28.jpg has already downloaded.
# Skipping: acne-closed-comedo-29.jpg has already downloaded.
# Skipping: acne-closed-comedo-3.jpg has already downloaded.
# Skipping: acne-closed-comedo-31.jpg has already downloaded.
# Skipping: acne-closed-comedo-32.jpg has already downloaded.
# Skipping: acne-closed-comedo-33.jpg has already downloaded.
# Skipping: acne-closed-comedo-34.jpg has already downloaded.
# Skipping: acne-closed-comedo-35.jpg has already downloaded.
# Skipping: acne-closed-comedo-36.jpg has already downloaded.
# Skipping: acne-closed-comedo-38.jpg has already downloaded.
# Skipping: acne-closed-comedo-39.jpg has already downloaded.
# Skipping: acne-closed-comedo-4.jpg has already downloaded.
# Skipping: acne-closed-comedo-40.jpg has already downloaded.
# Skipping: acne-closed-comedo-5.jpg has already downloaded.
# Skipping: acne-closed-comedo-6.jpg has already downloaded.
# Skipping: acne-closed-comedo-7.jpg has already downloaded.
# Skipping: acne-closed-comedo-8.jpg has already downloaded.
# Skipping: acne-closed-comedo-9.jpg has already downloaded.
# Skipping: acne-Closed-Comedo.jpg has already downloaded.
# Skipping: Comedones-Ears.jpg has already downloaded.
# Skipping: ComedonesEars-1.jpg has already downloaded.
# Skipping: acne-cystic-1.jpg has already downloaded.
# Skipping: acne-cystic-10.jpg has already downloaded.
# Skipping: acne-cystic-100.jpg has already downloaded.
# Skipping: acne-cystic-101.jpg has already downloaded.
# Skipping: acne-cystic-102.jpg has already downloaded.
# Skipping: acne-cystic-103.jpg has already downloaded.
# Skipping: acne-cystic-104.jpg has already downloaded.
# Skipping: acne-cystic-105.jpg has already downloaded.
# Skipping: acne-cystic-106.jpg has already downloaded.
# Skipping: acne-cystic-107.jpg has already downloaded.
# Skipping: acne-cystic-108.jpg has already downloaded.
# Skipping: acne-cystic-109.jpg has already downloaded.
# Skipping: acne-cystic-11.jpg has already downloaded.
# Skipping: acne-cystic-110.jpg has already downloaded.
# Skipping: acne-cystic-111.jpg has already downloaded.
# Skipping: acne-cystic-112.jpg has already downloaded.
# Skipping: acne-cystic-113.jpg has already downloaded.
# Skipping: acne-cystic-114.jpg has already downloaded.
# Skipping: acne-cystic-115.jpg has already downloaded.
# Skipping: acne-cystic-116.jpg has already downloaded.
# Skipping: acne-cystic-117.jpg has already downloaded.
# Skipping: acne-cystic-118.jpg has already downloaded.
# Skipping: acne-cystic-119.jpg has already downloaded.
# Skipping: acne-cystic-12.jpg has already downloaded.
# Skipping: acne-cystic-120.jpg has already downloaded.
# Skipping: acne-cystic-121.jpg has already downloaded.
# Skipping: acne-cystic-122.jpg has already downloaded.
# Skipping: acne-cystic-123.jpg has already downloaded.
# Skipping: acne-cystic-124.jpg has already downloaded.
# Skipping: acne-cystic-125.jpg has already downloaded.
# Skipping: acne-cystic-126.jpg has already downloaded.
# Skipping: acne-cystic-127.jpg has already downloaded.
# Skipping: acne-cystic-128.jpg has already downloaded.
# Skipping: acne-cystic-129.jpg has already downloaded.
# Skipping: acne-cystic-13.jpg has already downloaded.
# Skipping: acne-cystic-130.jpg has already downloaded.
# Skipping: acne-cystic-131.jpg has already downloaded.
# Skipping: acne-cystic-132.jpg has already downloaded.
# Skipping: acne-cystic-133.jpg has already downloaded.
# Skipping: acne-cystic-134.jpg has already downloaded.
# Skipping: acne-cystic-135.jpg has already downloaded.
# Skipping: acne-cystic-136.jpg has already downloaded.
# Skipping: acne-cystic-137.jpg has already downloaded.
# Skipping: acne-cystic-138.jpg has already downloaded.
# Skipping: acne-cystic-139.jpg has already downloaded.
# Skipping: acne-cystic-14.jpg has already downloaded.
# Skipping: acne-cystic-140.jpg has already downloaded.
# Skipping: acne-cystic-141.jpg has already downloaded.
# Skipping: acne-cystic-142.jpg has already downloaded.
# Skipping: acne-cystic-143.jpg has already downloaded.
# Skipping: acne-cystic-144.jpg has already downloaded.
# Skipping: acne-cystic-145.jpg has already downloaded.
# Skipping: acne-cystic-146.jpg has already downloaded.
# Skipping: acne-cystic-147.jpg has already downloaded.
# Skipping: acne-cystic-148.jpg has already downloaded.
# Skipping: acne-cystic-149.jpg has already downloaded.
# Skipping: acne-cystic-15.jpg has already downloaded.
# Skipping: acne-cystic-150.jpg has already downloaded.
# Skipping: acne-cystic-151.jpg has already downloaded.
# Skipping: acne-cystic-16.jpg has already downloaded.
# Skipping: acne-cystic-17.jpg has already downloaded.
# Skipping: acne-cystic-18.jpg has already downloaded.
# Skipping: acne-cystic-19.jpg has already downloaded.
# Skipping: acne-cystic-2.jpg has already downloaded.
# Skipping: acne-cystic-20.jpg has already downloaded.
# Skipping: acne-cystic-21.jpg has already downloaded.
# Skipping: acne-cystic-24.jpg has already downloaded.
# Skipping: acne-cystic-25.jpg has already downloaded.
# Skipping: acne-cystic-26.jpg has already downloaded.
# Skipping: acne-cystic-27.jpg has already downloaded.
# Skipping: acne-cystic-28.jpg has already downloaded.
# Skipping: acne-cystic-29.jpg has already downloaded.
# Skipping: acne-cystic-3.jpg has already downloaded.
# Skipping: acne-cystic-30.jpg has already downloaded.
# Skipping: acne-cystic-31.jpg has already downloaded.
# Skipping: acne-cystic-32.jpg has already downloaded.
# Skipping: acne-cystic-33.jpg has already downloaded.
# Skipping: acne-cystic-34.jpg has already downloaded.
# Skipping: acne-cystic-36.jpg has already downloaded.
# Skipping: acne-cystic-37.jpg has already downloaded.
# Skipping: acne-cystic-38.jpg has already downloaded.
# Skipping: acne-cystic-39.jpg has already downloaded.
# Skipping: acne-cystic-4.jpg has already downloaded.
# Skipping: acne-cystic-40.jpg has already downloaded.
# Skipping: acne-cystic-42.jpg has already downloaded.
# Skipping: acne-cystic-43.jpg has already downloaded.
# Skipping: acne-cystic-44.jpg has already downloaded.
# Skipping: acne-cystic-45.jpg has already downloaded.
# Skipping: acne-cystic-46.jpg has already downloaded.
# Skipping: acne-cystic-47.jpg has already downloaded.
# Skipping: acne-cystic-48.jpg has already downloaded.
# Skipping: acne-cystic-49.jpg has already downloaded.
# Skipping: acne-cystic-5.jpg has already downloaded.
# Skipping: acne-cystic-50.jpg has already downloaded.
# Skipping: acne-cystic-51.jpg has already downloaded.
# Skipping: acne-cystic-52.jpg has already downloaded.
# Skipping: acne-cystic-53.jpg has already downloaded.
# Skipping: acne-cystic-54.jpg has already downloaded.
# Skipping: acne-cystic-55.jpg has already downloaded.
# Skipping: acne-cystic-56.jpg has already downloaded.
# Skipping: acne-cystic-57.jpg has already downloaded.
# Skipping: acne-cystic-58.jpg has already downloaded.
# Skipping: acne-cystic-59.jpg has already downloaded.
# Skipping: acne-cystic-6.jpg has already downloaded.
# Skipping: acne-cystic-60.jpg has already downloaded.
# Skipping: acne-cystic-61.jpg has already downloaded.
# Skipping: acne-cystic-84.jpg has already downloaded.
# Skipping: acne-cystic-85.jpg has already downloaded.
# Skipping: acne-cystic-86.jpg has already downloaded.
# Skipping: acne-cystic-87.jpg has already downloaded.
# Skipping: acne-cystic-88.jpg has already downloaded.
# Skipping: acne-cystic-89.jpg has already downloaded.
# Skipping: acne-cystic-9.jpg has already downloaded.
# Skipping: acne-cystic-90.jpg has already downloaded.
# Skipping: acne-cystic-91.jpg has already downloaded.
# Skipping: acne-cystic-92.jpg has already downloaded.
# Skipping: acne-cystic-93.jpg has already downloaded.
# Skipping: acne-cystic-94.jpg has already downloaded.
# Skipping: acne-cystic-95.jpg has already downloaded.
# Skipping: acne-cystic-96.jpg has already downloaded.
# Skipping: acne-cystic-97.jpg has already downloaded.
# Skipping: acne-cystic-98.jpg has already downloaded.
# Skipping: acne-cystic-99.jpg has already downloaded.
# Skipping: acne-excoriated-1.jpg has already downloaded.
# Skipping: acne-excoriated-10.jpg has already downloaded.
# Skipping: acne-excoriated-11.jpg has already downloaded.
# Skipping: acne-excoriated-12.jpg has already downloaded.
# Skipping: acne-excoriated-13.jpg has already downloaded.
# Skipping: acne-excoriated-14.jpg has already downloaded.
# Skipping: acne-excoriated-15.jpg has already downloaded.
# Skipping: acne-excoriated-16.jpg has already downloaded.
# Skipping: acne-excoriated-17.jpg has already downloaded.
# Skipping: acne-excoriated-18.jpg has already downloaded.
# Skipping: acne-excoriated-19.jpg has already downloaded.
# Skipping: acne-excoriated-2.jpg has already downloaded.
# Skipping: acne-excoriated-20.jpg has already downloaded.
# Skipping: acne-excoriated-21.jpg has already downloaded.
# Skipping: acne-excoriated-22.jpg has already downloaded.
# Skipping: acne-excoriated-23.jpg has already downloaded.
# Skipping: acne-excoriated-24.jpg has already downloaded.
# Skipping: acne-excoriated-25.jpg has already downloaded.
# Skipping: acne-excoriated-26.jpg has already downloaded.
# Skipping: acne-excoriated-27.jpg has already downloaded.
# Skipping: acne-excoriated-28.jpg has already downloaded.
# Skipping: acne-excoriated-29.jpg has already downloaded.
# Skipping: acne-excoriated-3.jpg has already downloaded.
# Skipping: acne-excoriated-30.jpg has already downloaded.
# Skipping: acne-excoriated-4.jpg has already downloaded.
# Skipping: acne-excoriated-5.jpg has already downloaded.
# Skipping: acne-excoriated-6.jpg has already downloaded.
# Skipping: acne-excoriated-8.jpg has already downloaded.
# Skipping: acne-histology-3.jpg has already downloaded.
# Skipping: acne-histology-4.jpg has already downloaded.
# Skipping: acne-histology-5.jpg has already downloaded.
# Skipping: acne-infantile-1.jpg has already downloaded.
# Skipping: acne-infantile-10.jpg has already downloaded.
# Skipping: acne-infantile-11.jpg has already downloaded.
# Skipping: acne-infantile-12.jpg has already downloaded.
# Skipping: acne-infantile-13.jpg has already downloaded.
# Skipping: acne-infantile-14.jpg has already downloaded.
# Skipping: acne-infantile-15.jpg has already downloaded.
# Skipping: acne-infantile-16.jpg has already downloaded.
# Skipping: acne-infantile-2.jpg has already downloaded.
# Skipping: acne-infantile-3.jpg has already downloaded.
# Skipping: acne-infantile-4.jpg has already downloaded.
# Skipping: acne-infantile-5.jpg has already downloaded.
# Skipping: acne-infantile-6.jpg has already downloaded.
# Skipping: acne-infantile-7.jpg has already downloaded.
# Skipping: acne-infantile-8.jpg has already downloaded.
# Skipping: acne-infantile-9.jpg has already downloaded.
# Skipping: acne-mechanica-1.jpg has already downloaded.
# Skipping: acne-open-comedo-1.jpg has already downloaded.
# Skipping: acne-open-comedo-10.jpg has already downloaded.
# Skipping: acne-open-comedo-11.jpg has already downloaded.
# Skipping: acne-open-comedo-12.jpg has already downloaded.
# Skipping: acne-open-comedo-13.jpg has already downloaded.
# Skipping: acne-open-comedo-14.jpg has already downloaded.
# Skipping: acne-open-comedo-15.jpg has already downloaded.
# Skipping: acne-open-comedo-16.jpg has already downloaded.
# Skipping: acne-open-comedo-17.jpg has already downloaded.
# Skipping: acne-open-comedo-18.jpg has already downloaded.
# Skipping: acne-open-comedo-19.jpg has already downloaded.
# Skipping: acne-open-comedo-2.jpg has already downloaded.
# Skipping: acne-open-comedo-20.jpg has already downloaded.
# Skipping: acne-open-comedo-21.jpg has already downloaded.
# Skipping: acne-open-comedo-22.jpg has already downloaded.
# Skipping: acne-open-comedo-23.jpg has already downloaded.
# Skipping: acne-open-comedo-24.jpg has already downloaded.
# Skipping: acne-open-comedo-25.jpg has already downloaded.
# Skipping: acne-open-comedo-26.jpg has already downloaded.
# Skipping: acne-open-comedo-27.jpg has already downloaded.
# Skipping: acne-open-comedo-28.jpg has already downloaded.
# Skipping: acne-open-comedo-29.jpg has already downloaded.
# Skipping: acne-open-comedo-3.jpg has already downloaded.
# Skipping: acne-open-comedo-30.jpg has already downloaded.
# Skipping: acne-open-comedo-31.jpg has already downloaded.
# Skipping: acne-open-comedo-32.jpg has already downloaded.
# Skipping: acne-open-comedo-33.jpg has already downloaded.
# Skipping: acne-open-comedo-34.jpg has already downloaded.
# Skipping: acne-open-comedo-35.jpg has already downloaded.
# Skipping: acne-open-comedo-36.jpg has already downloaded.
# Skipping: acne-open-comedo-37.jpg has already downloaded.
# Skipping: acne-open-comedo-38.jpg has already downloaded.
# Skipping: acne-open-comedo-39.jpg has already downloaded.
# Skipping: acne-open-comedo-4.jpg has already downloaded.
# Skipping: acne-open-comedo-40.jpg has already downloaded.
# Skipping: acne-open-comedo-41.jpg has already downloaded.
# Skipping: acne-open-comedo-42.jpg has already downloaded.
# Skipping: acne-open-comedo-43.jpg has already downloaded.
# Skipping: acne-open-comedo-44.jpg has already downloaded.
# Skipping: acne-open-comedo-45.jpg has already downloaded.
# Skipping: acne-open-comedo-46.jpg has already downloaded.
# Skipping: acne-open-comedo-47.jpg has already downloaded.
# Skipping: acne-open-comedo-48.jpg has already downloaded.
# Skipping: acne-open-comedo-49.jpg has already downloaded.
# Skipping: acne-open-comedo-5.jpg has already downloaded.
# Skipping: acne-open-comedo-50.jpg has already downloaded.
# Skipping: acne-open-comedo-51.jpg has already downloaded.
# Skipping: acne-open-comedo-52.jpg has already downloaded.
# Skipping: acne-open-comedo-53.jpg has already downloaded.
# Skipping: acne-open-comedo-54.jpg has already downloaded.
# Skipping: acne-open-comedo-56.jpg has already downloaded.
# Skipping: acne-open-comedo-57.jpg has already downloaded.
# Skipping: acne-open-comedo-58.jpg has already downloaded.
# Skipping: acne-open-comedo-59.jpg has already downloaded.
# Skipping: acne-open-comedo-6.jpg has already downloaded.
# Skipping: acne-open-comedo-60.jpg has already downloaded.
# Skipping: acne-open-comedo-61.jpg has already downloaded.
# Skipping: acne-open-comedo-62.jpg has already downloaded.
# Skipping: acne-open-comedo-63.jpg has already downloaded.
# Skipping: acne-open-comedo-64.jpg has already downloaded.
# Skipping: acne-open-comedo-65.jpg has already downloaded.
# Skipping: acne-open-comedo-66.jpg has already downloaded.
# Skipping: acne-open-comedo-67.jpg has already downloaded.
# Skipping: acne-open-comedo-68.jpg has already downloaded.
# Skipping: acne-open-comedo-69.jpg has already downloaded.
# Skipping: acne-open-comedo-7.jpg has already downloaded.
# Skipping: acne-open-comedo-70.jpg has already downloaded.
# Skipping: acne-open-comedo-71.jpg has already downloaded.
# Skipping: acne-open-comedo-72.jpg has already downloaded.
# Skipping: acne-open-comedo-73.jpg has already downloaded.
# Skipping: acne-open-comedo-8.jpg has already downloaded.
# Skipping: acne-open-comedo-9.jpg has already downloaded.
# Skipping: acne-primary-lesion-2.jpg has already downloaded.
# Skipping: acne-primary-lesion-3.jpg has already downloaded.
# Skipping: acne-primary-lesion-4.jpg has already downloaded.
# Skipping: acne-primary-lesion-5.jpg has already downloaded.
# Skipping: acne-primary-lesion-6.jpg has already downloaded.
# Skipping: acne-primary-lesion-7.jpg has already downloaded.
# Skipping: 07Acne081101.jpg has already downloaded.
# Skipping: acne-pustular-1.jpg has already downloaded.
# Skipping: acne-pustular-10.jpg has already downloaded.
# Skipping: acne-pustular-12.jpg has already downloaded.
# Skipping: acne-pustular-13.jpg has already downloaded.
# Skipping: acne-pustular-14.jpg has already downloaded.
# Skipping: acne-pustular-15.jpg has already downloaded.
# Skipping: acne-pustular-16.jpg has already downloaded.
# Skipping: acne-pustular-17.jpg has already downloaded.
# Skipping: acne-pustular-18.jpg has already downloaded.
# Skipping: acne-pustular-20.jpg has already downloaded.
# Skipping: acne-pustular-21.jpg has already downloaded.
# Skipping: acne-pustular-22.jpg has already downloaded.
# Skipping: acne-pustular-23.jpg has already downloaded.
# Skipping: acne-pustular-24.jpg has already downloaded.
# Skipping: acne-pustular-25.jpg has already downloaded.
# Skipping: acne-pustular-26.jpg has already downloaded.
# Skipping: acne-pustular-27.jpg has already downloaded.
# Skipping: acne-pustular-28.jpg has already downloaded.
# Skipping: acne-pustular-29.jpg has already downloaded.
# Skipping: acne-pustular-3.jpg has already downloaded.
# Skipping: acne-pustular-30.jpg has already downloaded.
# Skipping: acne-pustular-31.jpg has already downloaded.
# Skipping: acne-pustular-32.jpg has already downloaded.
# Skipping: acne-pustular-33.jpg has already downloaded.
# Skipping: acne-pustular-34.jpg has already downloaded.
# Skipping: acne-pustular-35.jpg has already downloaded.
# Skipping: acne-pustular-36.jpg has already downloaded.
# Skipping: acne-pustular-37.jpg has already downloaded.
# Skipping: acne-pustular-38.jpg has already downloaded.
# Skipping: acne-pustular-39.jpg has already downloaded.
# Skipping: acne-pustular-4.jpg has already downloaded.
# Skipping: acne-pustular-40.jpg has already downloaded.
# Skipping: acne-pustular-41.jpg has already downloaded.
# Skipping: acne-pustular-42.jpg has already downloaded.
# Skipping: acne-pustular-43.jpg has already downloaded.
# Skipping: acne-pustular-44.jpg has already downloaded.
# Skipping: acne-pustular-45.jpg has already downloaded.
# Skipping: acne-pustular-46.jpg has already downloaded.
# Skipping: acne-pustular-47.jpg has already downloaded.
# Skipping: acne-pustular-48.jpg has already downloaded.
# Skipping: acne-pustular-49.jpg has already downloaded.
# Skipping: acne-pustular-5.jpg has already downloaded.
# Skipping: acne-pustular-50.jpg has already downloaded.
# Skipping: acne-pustular-51.jpg has already downloaded.
# Skipping: acne-pustular-52.jpg has already downloaded.
# Skipping: acne-pustular-53.jpg has already downloaded.
# Skipping: acne-pustular-54.jpg has already downloaded.
# Skipping: acne-pustular-55.jpg has already downloaded.
# Skipping: acne-pustular-56.jpg has already downloaded.
# Skipping: acne-pustular-57.jpg has already downloaded.
# Skipping: acne-pustular-58.jpg has already downloaded.
# Skipping: acne-pustular-59.jpg has already downloaded.
# Skipping: acne-pustular-6.jpg has already downloaded.
# Skipping: acne-pustular-60.jpg has already downloaded.
# Skipping: acne-pustular-61.jpg has already downloaded.
# Skipping: acne-pustular-62.jpg has already downloaded.
# Skipping: acne-pustular-63.jpg has already downloaded.
# Skipping: acne-pustular-64.jpg has already downloaded.
# Skipping: acne-pustular-65.jpg has already downloaded.
# Skipping: acne-pustular-66.jpg has already downloaded.
# Skipping: acne-pustular-67.jpg has already downloaded.
# Skipping: acne-pustular-68.jpg has already downloaded.
# Skipping: acne-pustular-69.jpg has already downloaded.
# Skipping: acne-pustular-7.jpg has already downloaded.
# Skipping: acne-pustular-70.jpg has already downloaded.
# Skipping: acne-pustular-71.jpg has already downloaded.
# Skipping: acne-pustular-72.jpg has already downloaded.
# Skipping: acne-pustular-73.jpg has already downloaded.
# Skipping: acne-pustular-74.jpg has already downloaded.
# Skipping: acne-pustular-8.jpg has already downloaded.
# Skipping: acne-pustular-9.jpg has already downloaded.
# Skipping: 07AcnePittedScars.jpg has already downloaded.
# Skipping: 07AcnePittedScars1.jpg has already downloaded.
# Skipping: acne-scar-1.jpg has already downloaded.
# Skipping: acne-scar-2.jpg has already downloaded.
# Skipping: acne-scar-3.jpg has already downloaded.
# Skipping: acne-scar-4.jpg has already downloaded.
# Skipping: acne-scar-5.jpg has already downloaded.
# Skipping: acne-scar-6.jpg has already downloaded.
# Skipping: acne-scar-7.jpg has already downloaded.
# Skipping: acne-scar-8.jpg has already downloaded.
# Skipping: acne-scar-9.jpg has already downloaded.
# Skipping: gram-negative-folliculitis-1.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-1.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-10.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-100.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-101.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-102.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-103.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-104.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-105.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-106.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-107.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-11.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-12.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-13.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-14.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-16.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-17.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-18.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-2.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-20.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-21.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-22.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-23.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-24.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-25.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-26.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-27.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-28.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-29.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-3.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-30.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-31.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-32.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-33.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-34.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-35.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-36.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-37.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-38.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-39.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-4.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-40.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-41.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-42.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-43.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-45.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-46.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-47.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-48.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-49.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-5.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-50.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-51.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-52.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-53.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-54.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-55.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-56.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-57.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-58.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-59.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-6.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-60.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-61.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-62.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-63.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-64.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-65.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-66.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-67.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-69.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-7.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-70.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-71.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-72.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-73.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-75.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-76.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-77.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-78.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-79.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-8.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-80.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-81.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-83.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-84.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-85.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-86.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-87.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-89.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-9.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-90.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-91.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-92.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-93.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-94.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-95.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-96.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-97.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-98.jpg has already downloaded.
# Skipping: hidradenitis-suppurativa-99.jpg has already downloaded.
# Skipping: hidradenitis-Suppurativa-Areola-1.jpg has already downloaded.
# Skipping: Hidradenitis-Suppurativa-Areola-2.jpg has already downloaded.
# Skipping: hyperhidrosis-1.jpg has already downloaded.
# Skipping: hyperhidrosis-2.jpg has already downloaded.
# Skipping: hyperhidrosis-3.jpg has already downloaded.
# Skipping: hyperhidrosis-4.jpg has already downloaded.
# Skipping: hyperhidrosis-5.jpg has already downloaded.
# Skipping: milia-1.jpg has already downloaded.
# Skipping: milia-10.jpg has already downloaded.
# Skipping: milia-11.jpg has already downloaded.
# Skipping: milia-12.jpg has already downloaded.
# Skipping: milia-13.jpg has already downloaded.
# Skipping: milia-14.jpg has already downloaded.
# Skipping: milia-15.jpg has already downloaded.
# Skipping: milia-16.jpg has already downloaded.
# Skipping: milia-17.jpg has already downloaded.
# Skipping: milia-18.jpg has already downloaded.
# Skipping: milia-19.jpg has already downloaded.
# Skipping: milia-3.jpg has already downloaded.
# Skipping: milia-4.jpg has already downloaded.
# Skipping: milia-5.jpg has already downloaded.
# Skipping: milia-6.jpg has already downloaded.
# Skipping: milia-8.jpg has already downloaded.
# Skipping: milia-9.jpg has already downloaded.
# Skipping: minocycline-pigmentation-1.jpg has already downloaded.
# Skipping: minocycline-pigmentation-10.jpg has already downloaded.
# Skipping: minocycline-pigmentation-12.jpg has already downloaded.
# Skipping: minocycline-pigmentation-2.jpg has already downloaded.
# Skipping: minocycline-pigmentation-3.jpg has already downloaded.
# Skipping: minocycline-pigmentation-4.jpg has already downloaded.
# Skipping: minocycline-pigmentation-8.jpg has already downloaded.
# Skipping: minocycline-pigmentation-9.jpg has already downloaded.
# Skipping: nevus-comedonicus-1.jpg has already downloaded.
# Skipping: nevus-comedonicus-2.jpg has already downloaded.
# Skipping: nevus-comedonicus-3.jpg has already downloaded.
# Skipping: nevus-comedonicus-4.jpg has already downloaded.
# Skipping: nevus-comedonicus-5.jpg has already downloaded.
# Skipping: nevus-comedonicus-8.jpg has already downloaded.
# Skipping: 07PerioralDermEye.jpg has already downloaded.
# Skipping: 07PerioralDermNose.jpg has already downloaded.
# Skipping: 07PerioralDermq.jpg has already downloaded.
# Skipping: 07PerioralSteroid1.jpg has already downloaded.
# Skipping: 07PerlecheAccutane.jpg has already downloaded.
# Skipping: 07SteroidPerioral.jpg has already downloaded.
# Skipping: 07SteroidPerioral1.jpg has already downloaded.
# Skipping: 07SteroidRosacea.jpg has already downloaded.
# Skipping: 07SteroidRosacea43.jpg has already downloaded.
# Skipping: 07SteroidRosGlab.jpg has already downloaded.
# Skipping: 08PerioralDerm0203.jpg has already downloaded.
# Skipping: 08PerioralDerm1.jpg has already downloaded.
# Skipping: perioral-dermatitis-1.jpg has already downloaded.
# Skipping: perioral-dermatitis-10.jpg has already downloaded.
# Skipping: perioral-dermatitis-100.jpg has already downloaded.
# Skipping: perioral-dermatitis-101.jpg has already downloaded.
# Skipping: perioral-dermatitis-102.jpg has already downloaded.
# Skipping: perioral-dermatitis-103.jpg has already downloaded.
# Skipping: perioral-dermatitis-104.jpg has already downloaded.
# Skipping: perioral-dermatitis-105.jpg has already downloaded.
# Skipping: perioral-dermatitis-106.jpg has already downloaded.
# Skipping: perioral-dermatitis-107.jpg has already downloaded.
# Skipping: perioral-dermatitis-108.jpg has already downloaded.
# Skipping: perioral-dermatitis-109.jpg has already downloaded.
# Skipping: perioral-dermatitis-11.jpg has already downloaded.
# Skipping: perioral-dermatitis-110.jpg has already downloaded.
# Skipping: perioral-dermatitis-111.jpg has already downloaded.
# Skipping: perioral-dermatitis-113.jpg has already downloaded.
# Skipping: perioral-dermatitis-114.jpg has already downloaded.
# Skipping: perioral-dermatitis-115.jpg has already downloaded.
# Skipping: perioral-dermatitis-116.jpg has already downloaded.
# Skipping: perioral-dermatitis-117.jpg has already downloaded.
# Skipping: perioral-dermatitis-118.jpg has already downloaded.
# Skipping: perioral-dermatitis-119.jpg has already downloaded.
# Skipping: perioral-dermatitis-12.jpg has already downloaded.
# Skipping: perioral-dermatitis-120.jpg has already downloaded.
# Skipping: perioral-dermatitis-121.jpg has already downloaded.
# Skipping: perioral-dermatitis-122.jpg has already downloaded.
# Skipping: perioral-dermatitis-123.jpg has already downloaded.
# Skipping: perioral-dermatitis-124.jpg has already downloaded.
# Skipping: perioral-dermatitis-125.jpg has already downloaded.
# Skipping: perioral-dermatitis-126.jpg has already downloaded.
# Skipping: perioral-dermatitis-127.jpg has already downloaded.
# Skipping: perioral-dermatitis-128.jpg has already downloaded.
# Skipping: perioral-dermatitis-129.jpg has already downloaded.
# Skipping: perioral-dermatitis-13.jpg has already downloaded.
# Skipping: perioral-dermatitis-130.jpg has already downloaded.
# Skipping: perioral-dermatitis-131.jpg has already downloaded.
# Skipping: perioral-dermatitis-132.jpg has already downloaded.
# Skipping: perioral-dermatitis-133.jpg has already downloaded.
# Skipping: perioral-dermatitis-134.jpg has already downloaded.
# Skipping: perioral-dermatitis-135.jpg has already downloaded.
# Skipping: perioral-dermatitis-136.jpg has already downloaded.
# Skipping: perioral-dermatitis-137.jpg has already downloaded.
# Skipping: perioral-dermatitis-138.jpg has already downloaded.
# Skipping: perioral-dermatitis-139.jpg has already downloaded.
# Skipping: perioral-dermatitis-14.jpg has already downloaded.
# Skipping: perioral-dermatitis-140.jpg has already downloaded.
# Skipping: perioral-dermatitis-141.jpg has already downloaded.
# Skipping: perioral-dermatitis-15.jpg has already downloaded.
# Skipping: perioral-dermatitis-16.jpg has already downloaded.
# Skipping: perioral-dermatitis-17.jpg has already downloaded.
# Skipping: perioral-dermatitis-18.jpg has already downloaded.
# Skipping: perioral-dermatitis-19.jpg has already downloaded.
# Skipping: perioral-dermatitis-2.jpg has already downloaded.
# Skipping: perioral-dermatitis-20.jpg has already downloaded.
# Skipping: perioral-dermatitis-21.jpg has already downloaded.
# Skipping: perioral-dermatitis-22.jpg has already downloaded.
# Skipping: perioral-dermatitis-23.jpg has already downloaded.
# Skipping: perioral-dermatitis-24.jpg has already downloaded.
# Skipping: perioral-dermatitis-25.jpg has already downloaded.
# Skipping: perioral-dermatitis-26.jpg has already downloaded.
# Skipping: perioral-dermatitis-27.jpg has already downloaded.
# Skipping: perioral-dermatitis-28.jpg has already downloaded.
# Skipping: perioral-dermatitis-29.jpg has already downloaded.
# Skipping: perioral-dermatitis-3.jpg has already downloaded.
# Skipping: perioral-dermatitis-30.jpg has already downloaded.
# Skipping: perioral-dermatitis-31.jpg has already downloaded.
# Skipping: perioral-dermatitis-32.jpg has already downloaded.
# Skipping: perioral-dermatitis-33.jpg has already downloaded.
# Skipping: perioral-dermatitis-34.jpg has already downloaded.
# Skipping: perioral-dermatitis-35.jpg has already downloaded.
# Skipping: perioral-dermatitis-36.jpg has already downloaded.
# Skipping: perioral-dermatitis-37.jpg has already downloaded.
# Skipping: perioral-dermatitis-38.jpg has already downloaded.
# Skipping: perioral-dermatitis-39.jpg has already downloaded.
# Skipping: perioral-dermatitis-4.jpg has already downloaded.
# Skipping: perioral-dermatitis-40.jpg has already downloaded.
# Skipping: perioral-dermatitis-41.jpg has already downloaded.
# Skipping: perioral-dermatitis-42.jpg has already downloaded.
# Skipping: perioral-dermatitis-43.jpg has already downloaded.
# Skipping: perioral-dermatitis-44.jpg has already downloaded.
# Skipping: perioral-dermatitis-45.jpg has already downloaded.
# Skipping: perioral-dermatitis-46.jpg has already downloaded.
# Skipping: perioral-dermatitis-47.jpg has already downloaded.
# Skipping: perioral-dermatitis-48.jpg has already downloaded.
# Skipping: perioral-dermatitis-49.jpg has already downloaded.
# Skipping: perioral-dermatitis-5.jpg has already downloaded.
# Skipping: perioral-dermatitis-50.jpg has already downloaded.
# Skipping: perioral-dermatitis-51.jpg has already downloaded.
# Skipping: perioral-dermatitis-52.jpg has already downloaded.
# Skipping: perioral-dermatitis-53.jpg has already downloaded.
# Skipping: perioral-dermatitis-54.jpg has already downloaded.
# Skipping: perioral-dermatitis-55.jpg has already downloaded.
# Skipping: perioral-dermatitis-56.jpg has already downloaded.
# Skipping: perioral-dermatitis-57.jpg has already downloaded.
# Skipping: perioral-dermatitis-58.jpg has already downloaded.
# Skipping: perioral-dermatitis-59.jpg has already downloaded.
# Skipping: perioral-dermatitis-82.jpg has already downloaded.
# Skipping: perioral-dermatitis-83.jpg has already downloaded.
# Skipping: perioral-dermatitis-84.jpg has already downloaded.
# Skipping: perioral-dermatitis-85.jpg has already downloaded.
# Skipping: perioral-dermatitis-86.jpg has already downloaded.
# Skipping: perioral-dermatitis-87.jpg has already downloaded.
# Skipping: perioral-dermatitis-88.jpg has already downloaded.
# Skipping: perioral-dermatitis-89.jpg has already downloaded.
# Skipping: perioral-dermatitis-9.jpg has already downloaded.
# Skipping: perioral-dermatitis-90.jpg has already downloaded.
# Skipping: perioral-dermatitis-91.jpg has already downloaded.
# Skipping: perioral-dermatitis-92.jpg has already downloaded.
# Skipping: perioral-dermatitis-93.jpg has already downloaded.
# Skipping: perioral-dermatitis-94.jpg has already downloaded.
# Skipping: perioral-dermatitis-95.jpg has already downloaded.
# Skipping: perioral-dermatitis-96.jpg has already downloaded.
# Skipping: perioral-dermatitis-97.jpg has already downloaded.
# Skipping: perioral-dermatitis-98.jpg has already downloaded.
# Skipping: perioral-dermatitis-99.jpg has already downloaded.
# Skipping: anal-Comedones-1.jpg has already downloaded.
# Skipping: anal-Comedones-2.jpg has already downloaded.
# Skipping: fordyce-spots-1.jpg has already downloaded.
# Skipping: fordyce-spots-2.jpg has already downloaded.
# Skipping: fordyce-spots-3.jpg has already downloaded.
# Skipping: fordyce-spots-4.jpg has already downloaded.
# Skipping: fordyce-spots-5.jpg has already downloaded.
# Skipping: fordyce-spots-6.jpg has already downloaded.
# Skipping: fordyce-spots-7.jpg has already downloaded.
# Skipping: fordyce-spots-lip.jpg has already downloaded.
# Skipping: Sebaceous-glands-Areola-1.jpg has already downloaded.
# Skipping: Sebaceous-glands-Areola-2.jpg has already downloaded.
# Skipping: Sebaceous-glands-Areola-3.jpg has already downloaded.
# Skipping: Sebaceous-glands-Areola-4.jpg has already downloaded.
# Skipping: Sebaceous-glands-labia-1.jpg has already downloaded.
# Skipping: sebaceous-glands-upper-lip-1.jpg has already downloaded.
# Skipping: sebaceous-glands-upper-lip-2.jpg has already downloaded.
# Skipping: 07rosacea010206OK.jpg has already downloaded.
# Skipping: 07RosaceaForehead.jpg has already downloaded.
# Skipping: 07RosaceaFulFAce.jpg has already downloaded.
# Skipping: 07RosaceaK0216.jpg has already downloaded.
# Skipping: 07RosaceaK02161.jpg has already downloaded.
# Skipping: 07RosaceaK02162.jpg has already downloaded.
# Skipping: 07RosaceaK02163.jpg has already downloaded.
# Skipping: 07RosaceaK02164.jpg has already downloaded.
# Skipping: 07RosaceaK02165.jpg has already downloaded.
# Skipping: 07RosaceaK02166.jpg has already downloaded.
# Skipping: 07RosaceaOK082806.jpg has already downloaded.
# Skipping: 07RosaceaOK0828062.jpg has already downloaded.
# Skipping: 07RosaceaOK0828063.jpg has already downloaded.
# Skipping: 07RosaceaTel011204.jpg has already downloaded.
# Skipping: 07rosaceaTreated091806OK.jpg has already downloaded.
# Skipping: 07sebDerem110105.jpg has already downloaded.
# Skipping: 07sebDerem1101051.jpg has already downloaded.
# Skipping: 07sebDerem1101052.jpg has already downloaded.
# Skipping: 07VascularFace0120.jpg has already downloaded.
# Skipping: 23VesselsNose.jpg has already downloaded.
# Skipping: 23VesselsNose1.jpg has already downloaded.
# Skipping: rosacea-1.jpg has already downloaded.
# Skipping: rosacea-10.jpg has already downloaded.
# Skipping: rosacea-100.jpg has already downloaded.
# Skipping: rosacea-101.jpg has already downloaded.
# Skipping: rosacea-102.jpg has already downloaded.
# Skipping: rosacea-103.jpg has already downloaded.
# Skipping: rosacea-104.jpg has already downloaded.
# Skipping: rosacea-105.jpg has already downloaded.
# Skipping: rosacea-106.jpg has already downloaded.
# Skipping: rosacea-107.jpg has already downloaded.
# Skipping: rosacea-108.jpg has already downloaded.
# Skipping: rosacea-109.jpg has already downloaded.
# Skipping: rosacea-11.jpg has already downloaded.
# Skipping: rosacea-110.jpg has already downloaded.
# Skipping: rosacea-111.jpg has already downloaded.
# Skipping: rosacea-112.jpg has already downloaded.
# Skipping: rosacea-113.jpg has already downloaded.
# Skipping: rosacea-114.jpg has already downloaded.
# Skipping: rosacea-115.jpg has already downloaded.
# Skipping: rosacea-116.jpg has already downloaded.
# Skipping: rosacea-117.jpg has already downloaded.
# Skipping: rosacea-118.jpg has already downloaded.
# Skipping: rosacea-12.jpg has already downloaded.
# Skipping: rosacea-13.jpg has already downloaded.
# Skipping: rosacea-14.jpg has already downloaded.
# Skipping: rosacea-15.jpg has already downloaded.
# Skipping: rosacea-16.jpg has already downloaded.
# Skipping: rosacea-17.jpg has already downloaded.
# Skipping: rosacea-18.jpg has already downloaded.
# Skipping: rosacea-19.jpg has already downloaded.
# Skipping: rosacea-2.jpg has already downloaded.
# Skipping: rosacea-20.jpg has already downloaded.
# Skipping: rosacea-21.jpg has already downloaded.
# Skipping: rosacea-22.jpg has already downloaded.
# Skipping: rosacea-23.jpg has already downloaded.
# Skipping: rosacea-24.jpg has already downloaded.
# Skipping: rosacea-25.jpg has already downloaded.
# Skipping: rosacea-26.jpg has already downloaded.
# Skipping: rosacea-27.jpg has already downloaded.
# Skipping: rosacea-28.jpg has already downloaded.
# Skipping: rosacea-29.jpg has already downloaded.
# Skipping: rosacea-3.jpg has already downloaded.
# Skipping: rosacea-30.jpg has already downloaded.
# Skipping: rosacea-31.jpg has already downloaded.
# Skipping: rosacea-32.jpg has already downloaded.
# Skipping: rosacea-33.jpg has already downloaded.
# Skipping: rosacea-34.jpg has already downloaded.
# Skipping: rosacea-35.jpg has already downloaded.
# Skipping: rosacea-36.jpg has already downloaded.
# Skipping: rosacea-37.jpg has already downloaded.
# Skipping: rosacea-38.jpg has already downloaded.
# Skipping: rosacea-39.jpg has already downloaded.
# Skipping: rosacea-4.jpg has already downloaded.
# Skipping: rosacea-40.jpg has already downloaded.
# Skipping: rosacea-41.jpg has already downloaded.
# Skipping: rosacea-42.jpg has already downloaded.
# Skipping: rosacea-43.jpg has already downloaded.
# Skipping: rosacea-44.jpg has already downloaded.
# Skipping: rosacea-45.jpg has already downloaded.
# Skipping: rosacea-46.jpg has already downloaded.
# Skipping: rosacea-47.jpg has already downloaded.
# Skipping: rosacea-48.jpg has already downloaded.
# Skipping: rosacea-49.jpg has already downloaded.
# Skipping: rosacea-5.jpg has already downloaded.
# Skipping: rosacea-50.jpg has already downloaded.
# Skipping: rosacea-51.jpg has already downloaded.
# Skipping: rosacea-52.jpg has already downloaded.
# Skipping: rosacea-53.jpg has already downloaded.
# Skipping: rosacea-54.jpg has already downloaded.
# Skipping: rosacea-55.jpg has already downloaded.
# Skipping: rosacea-56.jpg has already downloaded.
# Skipping: rosacea-57.jpg has already downloaded.
# Skipping: rosacea-58.jpg has already downloaded.
# Skipping: rosacea-59.jpg has already downloaded.
# Skipping: rosacea-6.jpg has already downloaded.
# Skipping: rosacea-60.jpg has already downloaded.
# Skipping: rosacea-61.jpg has already downloaded.
# Skipping: rosacea-62.jpg has already downloaded.
# Skipping: rosacea-63.jpg has already downloaded.
# Skipping: rosacea-64.jpg has already downloaded.
# Skipping: rosacea-65.jpg has already downloaded.
# Skipping: rosacea-67.jpg has already downloaded.
# Skipping: rosacea-68.jpg has already downloaded.
# Skipping: rosacea-69.jpg has already downloaded.
# Skipping: rosacea-7.jpg has already downloaded.
# Skipping: rosacea-70.jpg has already downloaded.
# Skipping: rosacea-71.jpg has already downloaded.
# Skipping: rosacea-72.jpg has already downloaded.
# Skipping: rosacea-73.jpg has already downloaded.
# Skipping: rosacea-74.jpg has already downloaded.
# Skipping: rosacea-75.jpg has already downloaded.
# Skipping: rosacea-76.jpg has already downloaded.
# Skipping: rosacea-77.jpg has already downloaded.
# Skipping: rosacea-78.jpg has already downloaded.
# Skipping: rosacea-79.jpg has already downloaded.
# Skipping: rosacea-8.jpg has already downloaded.
# Skipping: rosacea-80.jpg has already downloaded.
# Skipping: rosacea-81.jpg has already downloaded.
# Skipping: rosacea-82.jpg has already downloaded.
# Skipping: rosacea-83.jpg has already downloaded.
# Skipping: rosacea-84.jpg has already downloaded.
# Skipping: rosacea-85.jpg has already downloaded.
# Skipping: rosacea-86.jpg has already downloaded.
# Skipping: rosacea-87.jpg has already downloaded.
# Skipping: rosacea-88.jpg has already downloaded.
# Skipping: rosacea-89.jpg has already downloaded.
# Skipping: rosacea-9.jpg has already downloaded.
# Skipping: rosacea-90.jpg has already downloaded.
# Skipping: rosacea-91.jpg has already downloaded.
# Skipping: rosacea-92.jpg has already downloaded.
# Skipping: rosacea-93.jpg has already downloaded.
# Skipping: rosacea-94.jpg has already downloaded.
# Skipping: rosacea-95.jpg has already downloaded.
# Skipping: rosacea-96.jpg has already downloaded.
# Skipping: rosacea-97.jpg has already downloaded.
# Skipping: rosacea-98.jpg has already downloaded.
# Skipping: rosacea-99.jpg has already downloaded.
# Skipping: rosacea-granulomatous-1.jpg has already downloaded.
# Skipping: rosacea-granulomatous-2.jpg has already downloaded.
# Skipping: 07Rhinophyma1.jpg has already downloaded.
# Skipping: 07Rhinophyma1a.jpg has already downloaded.
# Skipping: 07Rhinophymaq.jpg has already downloaded.
# Skipping: 07rhnophymas032105.jpg has already downloaded.
# Skipping: 07rhnophymas0321051.jpg has already downloaded.
# Skipping: 07RosaceaMilia0120.jpg has already downloaded.
# Skipping: 07sebDerem1101051.jpg has already downloaded.
# Skipping: 07sebDerem1101052.jpg has already downloaded.
# Skipping: rhinophyma-1.jpg has already downloaded.
# Skipping: rhinophyma-2.jpg has already downloaded.
# Skipping: rhinophyma-3.jpg has already downloaded.
# Skipping: rhinophyma-4.jpg has already downloaded.
# Skipping: rhinophyma.jpg has already downloaded.
# Skipping: rosacea-nose-1.jpg has already downloaded.
# Skipping: rosacea-nose-10.jpg has already downloaded.
# Skipping: rosacea-nose-11.jpg has already downloaded.
# Skipping: rosacea-nose-12.jpg has already downloaded.
# Skipping: rosacea-nose-13.jpg has already downloaded.
# Skipping: rosacea-nose-14.jpg has already downloaded.
# Skipping: rosacea-nose-15.jpg has already downloaded.
# Skipping: rosacea-nose-16.jpg has already downloaded.
# Skipping: rosacea-nose-17.jpg has already downloaded.
# Skipping: rosacea-nose-18.jpg has already downloaded.
# Skipping: rosacea-nose-19.jpg has already downloaded.
# Skipping: rosacea-nose-2.jpg has already downloaded.
# Skipping: rosacea-nose-20.jpg has already downloaded.
# Skipping: rosacea-nose-21.jpg has already downloaded.
# Skipping: rosacea-nose-22.jpg has already downloaded.
# Skipping: rosacea-nose-23.jpg has already downloaded.
# Skipping: rosacea-nose-24.jpg has already downloaded.
# Skipping: rosacea-nose-25.jpg has already downloaded.
# Skipping: rosacea-nose-26.jpg has already downloaded.
# Skipping: rosacea-nose-28.jpg has already downloaded.
# Skipping: rosacea-nose-29.jpg has already downloaded.
# Skipping: rosacea-nose-3.jpg has already downloaded.
# Skipping: rosacea-nose-30.jpg has already downloaded.
# Skipping: rosacea-nose-31.jpg has already downloaded.
# Skipping: rosacea-nose-32.jpg has already downloaded.
# Skipping: rosacea-nose-33.jpg has already downloaded.
# Skipping: rosacea-nose-34.jpg has already downloaded.
# Skipping: rosacea-nose-35.jpg has already downloaded.
# Skipping: rosacea-nose-36.jpg has already downloaded.
# Skipping: rosacea-nose-37.jpg has already downloaded.
# Skipping: rosacea-nose-38.jpg has already downloaded.
# Skipping: rosacea-nose-39.jpg has already downloaded.
# ...
# Skipping: 13tineaCorporis0609011.jpg has already downloaded.
# Skipping: 13TineaGroinBorder.jpg has already downloaded.
# Skipping: tinea-primary-lesion-1.jpg has already downloaded.
# Skipping: tinea-primary-lesion-10.jpg has already downloaded.
# Skipping: tinea-primary-lesion-11.jpg has already downloaded.
# Skipping: tinea-primary-lesion-12.jpg has already downloaded.
# Skipping: tinea-primary-lesion-13.jpg has already downloaded.
# Skipping: tinea-primary-lesion-14.jpg has already downloaded.
# Skipping: tinea-primary-lesion-15.jpg has already downloaded.
# Skipping: tinea-primary-lesion-16.jpg has already downloaded.
# Skipping: tinea-primary-lesion-17.jpg has already downloaded.
# Skipping: tinea-primary-lesion-18.jpg has already downloaded.
# Skipping: tinea-primary-lesion-19.jpg has already downloaded.
# Skipping: tinea-primary-lesion-2.jpg has already downloaded.
# Skipping: tinea-primary-lesion-20.jpg has already downloaded.
# Skipping: tinea-primary-lesion-21.jpg has already downloaded.
# Skipping: tinea-primary-lesion-22.jpg has already downloaded.
# Skipping: tinea-primary-lesion-23.jpg has already downloaded.
# Skipping: tinea-primary-lesion-24.jpg has already downloaded.
# Skipping: tinea-primary-lesion-25.jpg has already downloaded.
# Skipping: tinea-primary-lesion-26.jpg has already downloaded.
# Skipping: tinea-primary-lesion-27.jpg has already downloaded.
# Skipping: tinea-primary-lesion-28.jpg has already downloaded.
# Skipping: tinea-primary-lesion-29.jpg has already downloaded.
# Skipping: tinea-primary-lesion-3.jpg has already downloaded.
# Skipping: tinea-primary-lesion-30.jpg has already downloaded.
# Skipping: tinea-primary-lesion-31.jpg has already downloaded.
# Skipping: tinea-primary-lesion-32.jpg has already downloaded.
# Skipping: tinea-primary-lesion-33.jpg has already downloaded.
# Skipping: tinea-primary-lesion-34.jpg has already downloaded.
# Skipping: tinea-primary-lesion-35.jpg has already downloaded.
# Skipping: tinea-primary-lesion-36.jpg has already downloaded.
# Skipping: tinea-primary-lesion-37.jpg has already downloaded.
# Skipping: tinea-primary-lesion-38.jpg has already downloaded.
# Skipping: tinea-primary-lesion-39.jpg has already downloaded.
# Skipping: tinea-primary-lesion-4.jpg has already downloaded.
# Skipping: tinea-primary-lesion-40.jpg has already downloaded.
# Skipping: tinea-primary-lesion-41.jpg has already downloaded.
# Skipping: tinea-primary-lesion-42.jpg has already downloaded.
# Skipping: tinea-primary-lesion-43.jpg has already downloaded.
# Skipping: tinea-primary-lesion-44.jpg has already downloaded.
# Skipping: tinea-primary-lesion-45.jpg has already downloaded.
# Skipping: tinea-primary-lesion-46.jpg has already downloaded.
# Skipping: tinea-primary-lesion-47.jpg has already downloaded.
# Skipping: tinea-primary-lesion-48.jpg has already downloaded.
# Skipping: tinea-primary-lesion-49.jpg has already downloaded.
# Skipping: tinea-primary-lesion-5.jpg has already downloaded.
# Skipping: tinea-primary-lesion-50.jpg has already downloaded.
# Skipping: tinea-primary-lesion-51.jpg has already downloaded.
# Skipping: tinea-primary-lesion-52.jpg has already downloaded.
# Skipping: tinea-primary-lesion-53.jpg has already downloaded.
# Skipping: tinea-primary-lesion-54.jpg has already downloaded.
# Skipping: tinea-primary-lesion-55.jpg has already downloaded.
# Skipping: tinea-primary-lesion-56.jpg has already downloaded.
# Skipping: tinea-primary-lesion-57.jpg has already downloaded.
# Skipping: tinea-primary-lesion-58.jpg has already downloaded.
# Skipping: tinea-primary-lesion-59.jpg has already downloaded.
# Skipping: tinea-primary-lesion-6.jpg has already downloaded.
# Skipping: tinea-primary-lesion-60.jpg has already downloaded.
# Skipping: tinea-primary-lesion-61.jpg has already downloaded.
# Skipping: tinea-primary-lesion-62.jpg has already downloaded.
# Skipping: tinea-primary-lesion-63.jpg has already downloaded.
# Skipping: tinea-primary-lesion-64.jpg has already downloaded.
# Skipping: tinea-primary-lesion-7.jpg has already downloaded.
# Skipping: tinea-primary-lesion-8.jpg has already downloaded.
# Skipping: tinea-primary-lesion-9.jpg has already downloaded.
# Skipping: 13tineaCApitis98-GP3.jpg has already downloaded.
# Skipping: 13TineaScalp010504.jpg has already downloaded.
# Skipping: 13TineaScalpMCanis060704.jpg has already downloaded.
# Skipping: tinea-scalp-1.jpg has already downloaded.
# Skipping: tinea-scalp-10.jpg has already downloaded.
# Skipping: tinea-scalp-11.jpg has already downloaded.
# Skipping: tinea-scalp-12.jpg has already downloaded.
# Skipping: tinea-scalp-13.jpg has already downloaded.
# Skipping: tinea-scalp-15.jpg has already downloaded.
# Skipping: tinea-scalp-16.jpg has already downloaded.
# Skipping: tinea-scalp-17.jpg has already downloaded.
# Skipping: tinea-scalp-18.jpg has already downloaded.
# Skipping: tinea-scalp-19.jpg has already downloaded.
# Skipping: tinea-scalp-2.jpg has already downloaded.
# Skipping: tinea-scalp-20.jpg has already downloaded.
# Skipping: tinea-scalp-21.jpg has already downloaded.
# Skipping: tinea-scalp-23.jpg has already downloaded.
# Skipping: tinea-scalp-24.jpg has already downloaded.
# Skipping: tinea-scalp-25.jpg has already downloaded.
# Skipping: tinea-scalp-26.jpg has already downloaded.
# Skipping: tinea-scalp-27.jpg has already downloaded.
# Skipping: tinea-scalp-28.jpg has already downloaded.
# Skipping: tinea-scalp-29.jpg has already downloaded.
# Skipping: tinea-scalp-3.jpg has already downloaded.
# Skipping: tinea-scalp-30.jpg has already downloaded.
# Skipping: tinea-scalp-31.jpg has already downloaded.
# Skipping: tinea-scalp-32.jpg has already downloaded.
# Skipping: tinea-scalp-33.jpg has already downloaded.
# Skipping: tinea-scalp-34.jpg has already downloaded.
# Skipping: tinea-scalp-35.jpg has already downloaded.
# Skipping: tinea-scalp-36.jpg has already downloaded.
# Skipping: tinea-scalp-37.jpg has already downloaded.
# Skipping: tinea-scalp-38.jpg has already downloaded.
# Skipping: tinea-scalp-39.jpg has already downloaded.
# Skipping: tinea-scalp-4.jpg has already downloaded.
# Skipping: tinea-scalp-40.jpg has already downloaded.
# Skipping: tinea-scalp-41.jpg has already downloaded.
# Skipping: tinea-scalp-42.jpg has already downloaded.
# Skipping: tinea-scalp-43.jpg has already downloaded.
# Skipping: tinea-scalp-44.jpg has already downloaded.
# Skipping: tinea-scalp-45.jpg has already downloaded.
# Skipping: tinea-scalp-46.jpg has already downloaded.
# Skipping: tinea-scalp-47.jpg has already downloaded.
# Skipping: tinea-scalp-48.jpg has already downloaded.
# Skipping: tinea-scalp-49.jpg has already downloaded.
# Skipping: tinea-scalp-5.jpg has already downloaded.
# Skipping: tinea-scalp-50.jpg has already downloaded.
# Skipping: tinea-scalp-51.jpg has already downloaded.
# Skipping: tinea-scalp-52.jpg has already downloaded.
# Skipping: tinea-scalp-53.jpg has already downloaded.
# Skipping: tinea-scalp-54.jpg has already downloaded.
# Skipping: tinea-scalp-55.jpg has already downloaded.
# Skipping: tinea-scalp-56.jpg has already downloaded.
# Skipping: tinea-scalp-57.jpg has already downloaded.
# Skipping: tinea-scalp-6.jpg has already downloaded.
# Skipping: tinea-scalp-60.jpg has already downloaded.
# Skipping: tinea-scalp-61.jpg has already downloaded.
# Skipping: tinea-scalp-62.jpg has already downloaded.
# Skipping: tinea-scalp-63.jpg has already downloaded.
# Skipping: tinea-scalp-64.jpg has already downloaded.
# Skipping: tinea-scalp-65.jpg has already downloaded.
# Skipping: tinea-scalp-66.jpg has already downloaded.
# Skipping: tinea-scalp-67.jpg has already downloaded.
# Skipping: tinea-scalp-68.jpg has already downloaded.
# Skipping: tinea-scalp-69.jpg has already downloaded.
# Skipping: tinea-scalp-7.jpg has already downloaded.
# Skipping: tinea-scalp-70.jpg has already downloaded.
# Skipping: tinea-scalp-71.jpg has already downloaded.
# Skipping: tinea-scalp-72.jpg has already downloaded.
# Skipping: tinea-scalp-8.jpg has already downloaded.
# Skipping: tinea-scalp-9.jpg has already downloaded.
# Skipping: 13tineaVersicolor041706.jpg has already downloaded.
# Skipping: tinea-versicolor-1.jpg has already downloaded.
# Skipping: tinea-versicolor-10.jpg has already downloaded.
# Skipping: tinea-versicolor-100.jpg has already downloaded.
# Skipping: tinea-versicolor-101.jpg has already downloaded.
# Skipping: tinea-versicolor-102.jpg has already downloaded.
# Skipping: tinea-versicolor-103.jpg has already downloaded.
# Skipping: tinea-versicolor-104.jpg has already downloaded.
# Skipping: tinea-versicolor-105.jpg has already downloaded.
# Skipping: tinea-versicolor-106.jpg has already downloaded.
# Skipping: tinea-versicolor-107.jpg has already downloaded.
# Skipping: tinea-versicolor-108.jpg has already downloaded.
# Skipping: tinea-versicolor-109.jpg has already downloaded.
# Skipping: tinea-versicolor-11.jpg has already downloaded.
# Skipping: tinea-versicolor-110.jpg has already downloaded.
# Skipping: tinea-versicolor-111.jpg has already downloaded.
# Skipping: tinea-versicolor-112.jpg has already downloaded.
# Skipping: tinea-versicolor-113.jpg has already downloaded.
# Skipping: tinea-versicolor-114.jpg has already downloaded.
# Skipping: tinea-versicolor-115.jpg has already downloaded.
# Skipping: tinea-versicolor-116.jpg has already downloaded.
# Skipping: tinea-versicolor-117.jpg has already downloaded.
# Skipping: tinea-versicolor-118.jpg has already downloaded.
# Skipping: tinea-versicolor-119.jpg has already downloaded.
# Skipping: tinea-versicolor-12.jpg has already downloaded.
# Skipping: tinea-versicolor-120.jpg has already downloaded.
# Skipping: tinea-versicolor-121.jpg has already downloaded.
# Skipping: tinea-versicolor-122.jpg has already downloaded.
# Skipping: tinea-versicolor-123.jpg has already downloaded.
# Skipping: tinea-versicolor-125.jpg has already downloaded.
# Skipping: tinea-versicolor-126.jpg has already downloaded.
# Skipping: tinea-versicolor-127.jpg has already downloaded.
# Skipping: tinea-versicolor-128.jpg has already downloaded.
# Skipping: tinea-versicolor-129.jpg has already downloaded.
# Skipping: tinea-versicolor-13.jpg has already downloaded.
# Skipping: tinea-versicolor-130.jpg has already downloaded.
# Skipping: tinea-versicolor-131.jpg has already downloaded.
# Skipping: tinea-versicolor-132.jpg has already downloaded.
# Skipping: tinea-versicolor-133.jpg has already downloaded.
# Skipping: tinea-versicolor-134.jpg has already downloaded.
# Skipping: tinea-versicolor-135.jpg has already downloaded.
# Skipping: tinea-versicolor-136.jpg has already downloaded.
# Skipping: tinea-versicolor-137.jpg has already downloaded.
# Skipping: tinea-versicolor-138.jpg has already downloaded.
# Skipping: tinea-versicolor-139.jpg has already downloaded.
# Skipping: tinea-versicolor-14.jpg has already downloaded.
# Skipping: tinea-versicolor-140.jpg has already downloaded.
# Skipping: tinea-versicolor-141.jpg has already downloaded.
# Skipping: tinea-versicolor-142.jpg has already downloaded.
# Skipping: tinea-versicolor-143.jpg has already downloaded.
# Skipping: tinea-versicolor-144.jpg has already downloaded.
# Skipping: tinea-versicolor-145.jpg has already downloaded.
# Skipping: tinea-versicolor-146.jpg has already downloaded.
# Skipping: tinea-versicolor-147.jpg has already downloaded.
# Skipping: tinea-versicolor-148.jpg has already downloaded.
# Skipping: tinea-versicolor-149.jpg has already downloaded.
# Skipping: tinea-versicolor-15.jpg has already downloaded.
# Skipping: tinea-versicolor-150.jpg has already downloaded.
# Skipping: tinea-versicolor-151.jpg has already downloaded.
# Skipping: tinea-versicolor-152.jpg has already downloaded.
# Skipping: tinea-versicolor-153.jpg has already downloaded.
# Skipping: tinea-versicolor-154.jpg has already downloaded.
# Skipping: tinea-versicolor-155.jpg has already downloaded.
# Skipping: tinea-versicolor-156.jpg has already downloaded.
# Skipping: tinea-versicolor-157.jpg has already downloaded.
# Skipping: tinea-versicolor-158.jpg has already downloaded.
# Skipping: tinea-versicolor-159.jpg has already downloaded.
# Skipping: tinea-versicolor-16.jpg has already downloaded.
# Skipping: tinea-versicolor-160.jpg has already downloaded.
# Skipping: tinea-versicolor-161.jpg has already downloaded.
# Skipping: tinea-versicolor-162.jpg has already downloaded.
# Skipping: tinea-versicolor-163.jpg has already downloaded.
# Skipping: tinea-versicolor-164.jpg has already downloaded.
# Skipping: tinea-versicolor-165.jpg has already downloaded.
# Skipping: tinea-versicolor-166.jpg has already downloaded.
# Skipping: tinea-versicolor-167.jpg has already downloaded.
# Skipping: tinea-versicolor-168.jpg has already downloaded.
# Skipping: tinea-versicolor-169.jpg has already downloaded.
# Skipping: tinea-versicolor-17.jpg has already downloaded.
# Skipping: tinea-versicolor-170.jpg has already downloaded.
# Skipping: tinea-versicolor-171.jpg has already downloaded.
# Skipping: tinea-versicolor-172.jpg has already downloaded.
# Skipping: tinea-versicolor-173.jpg has already downloaded.
# Skipping: tinea-versicolor-174.jpg has already downloaded.
# Skipping: tinea-versicolor-175.jpg has already downloaded.
# Skipping: tinea-versicolor-176.jpg has already downloaded.
# Skipping: tinea-versicolor-177.jpg has already downloaded.
# Skipping: tinea-versicolor-178.jpg has already downloaded.
# Skipping: tinea-versicolor-179.jpg has already downloaded.
# Skipping: tinea-versicolor-18.jpg has already downloaded.
# Skipping: tinea-versicolor-180.jpg has already downloaded.
# Skipping: tinea-versicolor-181.jpg has already downloaded.
# Skipping: tinea-versicolor-182.jpg has already downloaded.
# Skipping: tinea-versicolor-183.jpg has already downloaded.
# Skipping: tinea-versicolor-184.jpg has already downloaded.
# Skipping: tinea-versicolor-185.jpg has already downloaded.
# Skipping: tinea-versicolor-186.jpg has already downloaded.
# Skipping: tinea-versicolor-187.jpg has already downloaded.
# Skipping: tinea-versicolor-188.jpg has already downloaded.
# Skipping: tinea-versicolor-189.jpg has already downloaded.
# Skipping: tinea-versicolor-19.jpg has already downloaded.
# Skipping: tinea-versicolor-190.jpg has already downloaded.
# Skipping: tinea-versicolor-191.jpg has already downloaded.
# Skipping: tinea-versicolor-192.jpg has already downloaded.
# Skipping: tinea-versicolor-193.jpg has already downloaded.
# Skipping: tinea-versicolor-194.jpg has already downloaded.
# Skipping: tinea-versicolor-195.jpg has already downloaded.
# Skipping: tinea-versicolor-196.jpg has already downloaded.
# Skipping: tinea-versicolor-79.jpg has already downloaded.
# Skipping: tinea-versicolor-8.jpg has already downloaded.
# Skipping: tinea-versicolor-80.jpg has already downloaded.
# Skipping: tinea-versicolor-81.jpg has already downloaded.
# Skipping: tinea-versicolor-82.jpg has already downloaded.
# Skipping: tinea-versicolor-83.jpg has already downloaded.
# Skipping: tinea-versicolor-84.jpg has already downloaded.
# Skipping: tinea-versicolor-85.jpg has already downloaded.
# Skipping: tinea-versicolor-86.jpg has already downloaded.
# Skipping: tinea-versicolor-87.jpg has already downloaded.
# Skipping: tinea-versicolor-88.jpg has already downloaded.
# Skipping: tinea-versicolor-89.jpg has already downloaded.
# Skipping: tinea-versicolor-9.jpg has already downloaded.
# Skipping: tinea-versicolor-91.jpg has already downloaded.
# Skipping: tinea-versicolor-92.jpg has already downloaded.
# Skipping: tinea-versicolor-94.jpg has already downloaded.
# Skipping: tinea-versicolor-95.jpg has already downloaded.
# Skipping: tinea-versicolor-96.jpg has already downloaded.
# Skipping: tinea-versicolor-97.jpg has already downloaded.
# Skipping: tinea-versicolor-99.jpg has already downloaded.
# Skipping: tt-tonsurans-adult-1.jpg has already downloaded.
# Skipping: tt-tonsurans-adult-2.jpg has already downloaded.
# Download complete for: Tinea Ringworm Candidiasis and other Fungal Infections
# Processing class: Urticaria Hives
# Found Dir
# Download complete for: Urticaria Hives
# Processing class: Vascular Tumors
# Found Dir
# Download complete for: Vascular Tumors
# Processing class: Vasculitis Photos
# Found Dir
# Download complete for: Vasculitis Photos
# Processing class: Warts Molluscum and other Viral Infections
# Found Dir
# Download complete for: Warts Molluscum and other Viral Infections
# Scraping Complete.

# %% [markdown]
# # All Images from Derment website are saved in downloaded_dataset via web scrapping
